# %%
import numpy as np

# %% [markdown]
# ## Question 1

# %%
a = np.random.random([10,1])

# %%
a
# Out:
# array([[0.68167607],
#        [0.90815646],
#        [0.67724211],
#        [0.71294118],
#        [0.40442893],
#        [0.350172  ],
#        [0.90509202],
#        [0.40892049],
#        [0.24168435],
#        [0.62720456]])

# %%
np.mean(a)
# Out:
# 0.5917518167776448

# %% [markdown]
# ## Question 2

# %%
b= np.random.random([20,1])

# %%
b
# Out:
# array([[0.81801909],
#        [0.95328914],
#        [0.14308963],
#        [0.5979051 ],
#        [0.78397349],
#        [0.70118449],
#        [0.65458467],
#        [0.74095981],
#        [0.45273035],
#        [0.39258392],
#        [0.50011758],
#        [0.2615681 ],
#        [0.19406516],
#        [0.39553724],
#        [0.0396719 ],
#        [0.60474023],
#        [0.74395279],
#        [0.19211772],
#        [0.64282431],
#        [0.21911494]])

# %%
np.var(b)
# Out:
# 0.06491018348186786

# %%
np.std(b)
# Out:
# 0.25477477010463156

# %% [markdown]
# ## Question 3

# %%
x= np.random.random([10,20])

# %%
y = np.random.random([20,25])

# %%
c = np.dot(x,y)

# %%
c
# Out:
# array([[6.82856038, 7.47881772, 7.28799737, 6.63649521, 6.58925119,
#         8.01423635, 5.86464253, 6.64777863, 7.22150816, 6.9046932 ,
#         6.44474889, 7.03734079, 7.81294924, 6.78609793, 7.16493495,
#         6.19520445, 6.7816841 , 6.92167421, 7.60594334, 8.09697996,
#         7.33201129, 6.63529882, 6.0786704 , 7.20598887, 5.47580483],
#        [5.57302916, 4.90627284, 5.22857338, 4.76455351, 4.28216953,
#         6.34230579, 4.24512356, 5.5054312 , 5.52497137, 5.65230577,
#         4.59574449, 5.69433831, 5.59897645, 6.16116235, 5.24442959,
#         5.02000356, 4.65324559, 5.01689454, 5.72827913, 6.72970905,
#         5.5770531 , 4.73662783, 4.04973474, 5.70384694, 3.98836628],
#        [6.21114878, 5.88581025, 6.61761401, 5.48975796, 5.31152098,
#         7.27309742, 4.78873712, 6.15761642, 6.85506065, 6.95671008,
#         6.25133602, 5.69361141, 6.8268119 , 7.71362698, 6.37206287,
#         5.48194529, 6.66271846, 5.76726157, 6.85008996, 7.8607155 ,
#         7.12000979, 5.15966049, 6.08803743, 6.42467102, 5.15323821],
#        [5.84759706, 5.80224923, 5.67129052, 5.31769015, 5.2380828 ,
#         6.40002565, 4.46847532, 5.29642345, 5.75531171, 5.76182425,
#         4.7285838 , 5.34503527, 6.24492568, 5.91882045, 4.91691609,
#         4.75418594, 5.18369535, 5.04653779, 5.61202945, 6.98080798,
#         5.72717587, 5.31123185, 4.22383208, 5.93272301, 3.82917731],
#        [6.27666985, 7.11443302, 6.67531089, 5.54226384, 6.32302431,
#         7.08958334, 4.87853838, 5.48052006, 6.31187503, 6.0150101 ,
#         5.77700094, 5.49445209, 6.96350382, 6.58637598, 6.06965939,
#         4.94620658, 6.20819766, 5.84811753, 6.1985225 , 7.72344214,
#         6.55107964, 5.81814181, 5.77702799, 6.7027339 , 4.77513077],
#        [4.62776998, 4.87927923, 4.91520554, 4.03354585, 4.37285768,
#         5.44930094, 3.7656948 , 4.65269916, 5.07510235, 4.34783775,
#         4.18480655, 4.56466837, 4.90911665, 4.9536558 , 4.79847578,
#         3.50038714, 3.93221011, 4.88994745, 5.15017329, 5.36421208,
#         5.21892587, 4.04466911, 3.86493821, 5.60291404, 3.55638175],
#        [5.10039333, 5.51380895, 5.20800104, 4.2650906 , 4.35524896,
#         6.09308309, 4.38607802, 4.72993825, 5.46142928, 4.99373097,
#         4.57172037, 4.81099157, 5.25578308, 5.51872903, 4.90625895,
#         4.48998371, 4.38511738, 5.02948633, 5.30202775, 5.9032833 ,
#         5.61993779, 4.38668192, 4.69448813, 5.2594351 , 4.28850795],
#        [5.87124168, 6.56979818, 6.57430715, 5.47884813, 5.54519525,
#         6.96758777, 5.08310636, 6.05007965, 6.44363554, 6.67152092,
#         5.85788005, 5.43690864, 6.55972903, 6.7596698 , 5.68488563,
#         4.92761949, 6.00102269, 6.13853783, 6.29692442, 7.54718586,
#         6.43267682, 5.43463087, 5.54515477, 6.45846706, 5.14657098],
#        [4.973592  , 5.37943415, 5.10827886, 4.40547668, 5.2260881 ,
#         4.58125166, 3.92417103, 3.75709013, 4.10002532, 4.52955882,
#         4.15536345, 4.16133304, 4.95060227, 5.03250485, 3.3470451 ,
#         3.8185125 , 5.17606532, 3.82889345, 4.06882252, 5.72247207,
#         4.74221955, 4.55404547, 3.87576301, 5.48987814, 3.35749661],
#        [5.09775636, 5.90133433, 5.49748782, 4.95138818, 5.76254343,
#         6.3687883 , 4.45970414, 4.54570732, 5.33984023, 5.39240985,
#         5.26403674, 4.50721783, 6.19409147, 5.46201135, 5.31155316,
#         4.45142273, 5.69973343, 5.2396405 , 5.56390885, 6.82585646,
#         5.674417  , 4.93025141, 5.22007742, 6.10689826, 4.14337232]])

# %%
c.shape
# Out:
# (10, 25)

# %%
np.sum(c)
# Out:
# 1385.8514290255723

# %% [markdown]
# ## Question 4

# %%
w = np.arange(10).reshape(10,1)

# %%
def myfunc(x,axis):
    return 1/(1+ np.exp(-x))

# %%
np.apply_over_axes(myfunc,w,1)
# Out:
# array([[0.5       ],
#        [0.73105858],
#        [0.88079708],
#        [0.95257413],
#        [0.98201379],
#        [0.99330715],
#        [0.99752738],
#        [0.99908895],
#        [0.99966465],
#        [0.99987661]])
